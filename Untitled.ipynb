# %%
import pandas as pd


data = pd.read_csv('dataMSA_full.csv')  
data.columns = data.columns.str.lower()
data.set_index('area', inplace=True)

index = ['San Antonio-New Braunfels', 'Houston-The Woodlands-Sugar Land', 'El Paso', 'Dallas-Fort Worth-Arlington', 'Austin-Round Rock']
big_cities = data.drop(index=data.index.difference(['San Antonio-New Braunfels', 'Houston-The Woodlands-Sugar Land', 'Fort Worth-Arlington', 'El Paso', 'Dallas-Plano-Irving', 'Austin-Round Rock']))
big_cities
# Out:
#                            year  quarter  overall_hpi  overall_yoy  \
# area
# Austin-Round Rock          1999        1   100.000000          NaN
# Austin-Round Rock          1999        2   103.564194          NaN
# Austin-Round Rock          1999        3   105.788651          NaN
# Austin-Round Rock          1999        4   106.862772          NaN
# Austin-Round Rock          2000        1   110.855112     0.108551
# ...                         ...      ...          ...          ...
# San Antonio-New Braunfels  2019        2   134.386082     0.045647
# San Antonio-New Braunfels  2019        3   135.083315     0.040641
# San Antonio-New Braunfels  2019        4   135.066486     0.041130
# San Antonio-New Braunfels  2020        1   136.312462     0.035022
# San Antonio-New Braunfels  2020        2   139.101132     0.035086
#
#                               low_hpi   low_yoy     mid_hpi   mid_yoy  \
# area
# Austin-Round Rock          100.000000       NaN  100.000000       NaN
# ...
